# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://shopee.tw")

# %%
driver.get_cookies()
# Out:
# [{'domain': '.shopee.tw',
#   'expiry': 2175493795.69859,
#   'httpOnly': False,
#   'name': 'SPC_U',
#   'path': '/',
#   'secure': False,
#   'value': '-'},
#  {'domain': '.shopee.tw',
#   'expiry': 1544777397,
#   'httpOnly': False,
#   'name': 'AMP_TOKEN',
#   'path': '/',
#   'secure': False,
#   'value': '%24NOT_FOUND'},
#  {'domain': '.shopee.tw',
#   'expiry': 1552549793,
#   'httpOnly': False,
#   'name': '_gcl_au',
#   'path': '/',
#   'secure': False,
#   'value': '1.1.1101664825.1544773794'},
#  {'domain': '.shopee.tw',
#   'expiry': 2175493795.698329,
#   'httpOnly': False,
#   'name': 'SPC_F',
#   'path': '/',
#   'secure': False,
#   'value': 'XzR3uXsVQetCOAYWou0L7ueYBVzveFzi'},
#  {'domain': 'shopee.tw',
#   'httpOnly': False,
#   'name': 'bannerShown',
#   'path': '/',
#   'secure': False,
#   'value': 'true'},
#  {'domain': '.shopee.tw',
#   'expiry': 1544781576,
#   'httpOnly': False,
#   'name': '_fbp',
#   'path': '/',
#   'secure': False,
# ...

# %%
#cookies組合
#c=;.join['{}={}'.format(item.get('name'),itme.get('value'))for itme in driver.get_cookies(): ]
# Out:
#   File "<ipython-input-18-fb31be6149a6>", line 2
#     c=;.join['{}={}'.format(item.get('name'),itme.get('value'))for itme in driver.get_cookies(): ]
#       ^
# SyntaxError: invalid syntax

# %%
import requests
import json
headers ={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36',
}
res = requests.get('https://shopee.tw/api/v2/search_items/?by=relevancy&keyword=%E8%A1%8C%E6%9D%8E%E7%AE%B1&limit=50&match_id=1611&newest=0&order=desc&page_type=search',headers=headers)

print (res.text)
# Out:
# {"show_disclaimer":true,"adjust":{"count":205813},"version":"d2b8fd2438ea3fa706fb61a06d32161e","algorithm":"Default|RankServer.IntentionLayer.RawSearch,Default|RankServer.adssearch.useinte","total_count":131577,"error":null,"total_ads_count":107,"nomore":true,"price_adjust":{"count":205813},"suggestion_algorithm":0,"items":[{"itemid":26037441,"welcome_package_info":null,"liked":true,"recommendation_info":null,"bundle_deal_info":null,"price_max_before_discount":null,"image":"2d33a23e7bedd1852a4797c6dc8","is_cc_installment_payment_eligible":true,"shopid":213007,"can_use_wholesale":false,"group_buy_info":null,"currency":"TWD","raw_discount":null,"show_free_shipping":true,"video_info_list":[{"duration":118,"video_id":"I3wCjV","thumb_url":"f2122158aa50fe60263802"}],"ads_keyword":"\u884c\u674e\u7bb1","collection_id":null,"images":["2d33a23e7bedd1852a4797","1bea6b84b4aa5e95c38e71","514e85820c2496668e463f","3828b48f6c95b46ef6785a","775b79c4fed17d0ee2e2f9","7c2d7b8a0a9b0379ca5578","1e03be1fba
# ...

# %%
res
# Out:
# <Response [200]>
